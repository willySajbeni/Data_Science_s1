# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
data = pd.read_csv('mtcars.csv')
data.columns=['cars_name','mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
data.head()
# Out:
#            cars_name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
data.sum()
# Out:
# cars_name    Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...
# mpg                                                      642.9
# cyl                                                        198
# disp                                                    7383.1
# hp                                                        4694
# drat                                                    115.09
# wt                                                     102.952
# qsec                                                    571.16
# vs                                                          14
# am                                                          13
# gear                                                       118
# carb                                                        90
# dtype: object

# %%
data.sum(axis=1)
# Out:
# /var/folders/5v/6sdcd_ln4fxb_wj2944sknw00000gn/T/ipykernel_68329/1923841176.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.sum(axis=1)
# 0     328.980
# 1     329.795
# 2     259.580
# 3     426.135
# 4     590.310
# 5     385.540
# 6     656.920
# 7     270.980
# 8     299.570
# 9     350.460
# 10    349.660
# 11    510.740
# 12    511.500
# 13    509.850
# 14    728.560
# 15    726.644
# 16    725.695
# 17    213.850
# 18    195.165
# 19    206.955
# 20    273.775
# 21    519.650
# 22    506.085
# 23    646.280
# 24    631.175
# 25    208.215
# 26    272.570
# 27    273.683
# 28    670.690
# 29    379.590
# 30    694.710
# 31    288.890
# dtype: float64

# %%
data.median()
# Out:
# /var/folders/5v/6sdcd_ln4fxb_wj2944sknw00000gn/T/ipykernel_68329/4184645713.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
data.mean()
# Out:
# /var/folders/5v/6sdcd_ln4fxb_wj2944sknw00000gn/T/ipykernel_68329/531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
data.max()
# Out:
# cars_name    Volvo 142E
# mpg                33.9
# cyl                   8
# disp              472.0
# hp                  335
# drat               4.93
# wt                5.424
# qsec               22.9
# vs                    1
# am                    1
# gear                  5
# carb                  8
# dtype: object

# %%
data.mpg.idxmax()
# Out:
# 19

# %%
data.std()
# Out:
# /var/folders/5v/6sdcd_ln4fxb_wj2944sknw00000gn/T/ipykernel_68329/2723740006.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
data.var()
# Out:
# /var/folders/5v/6sdcd_ln4fxb_wj2944sknw00000gn/T/ipykernel_68329/445316826.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# mpg        36.324103
# cyl         3.189516
# disp    15360.799829
# hp       4700.866935
# drat        0.285881
# wt          0.957379
# qsec        3.193166
# vs          0.254032
# am          0.248992
# gear        0.544355
# carb        2.608871
# dtype: float64

# %%
data.cumsum()
# Out:
#                                             cars_name    mpg  cyl    disp  \
# 0                                           Mazda RX4   21.0    6   160.0
# 1                              Mazda RX4Mazda RX4 Wag   42.0   12   320.0
# 2                    Mazda RX4Mazda RX4 WagDatsun 710   64.8   16   428.0
# 3      Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive   86.2   22   686.0
# 4   Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  104.9   30  1046.0
# 5   Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  123.0   36  1271.0
# 6   Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  137.3   44  1631.0
# 7   Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  161.7   48  1777.7
# 8   Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  184.5   52  1918.5
# 9   Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  203.7   58  2086.1
# 10  Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  221.5   64  2253.7
# 11  Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...  237.9   72  2529.5
# ...

# %%
data.gear.value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...
